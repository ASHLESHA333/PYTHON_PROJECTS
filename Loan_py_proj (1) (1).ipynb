# %% [markdown]
# **IMPORT FILES**

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Loan_dataset.csv')

# %%
df
# Out:
#                                     Loan ID  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048
# 1      4771cc26-131a-45db-b5aa-537ea4ba5342
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4      d4062e70-befa-4995-8643-a0de73938182
# ...                                     ...
# 83641  69e80370-92c2-4bf9-88fc-7584a9dd303d
# 83642  be4f56d6-1b66-4be0-81b0-3c44d9b1f7b6
# 83643  e5d96cb7-400f-49b2-905c-b45ee191d654
# 83644  ce743e70-ff42-4f6a-ad68-2ce3a6cd4aa7
# 83645     cb66e006-cc95-4898-890e-a5f7ff23a
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 0      981165ec-3274-42f5-a3b4-d104041a9ca9   Fully Paid             445412.0
# 1      2de017a3-2e01-49cb-a581-08169e83be29   Fully Paid             262328.0
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725   Fully Paid           99999999.0
# 3      e777faab-98ae-45af-9a86-7ce5b33b1011   Fully Paid             347666.0
# 4      81536ad9-5ccf-4eb8-befb-47a4d608658e   Fully Paid             176220.0
# ...                                     ...          ...                  ...
# 83641  5dd13ae7-f7d5-45d9-aabf-60efbd12da97  Charged Off             270072.0
# 83642  69de7205-e7a5-4618-9cd8-ea898b68c6fb   Fully Paid           99999999.0
# 83643  bbeb9483-5d66-4038-9e14-306bf78e28c0   Fully Paid             177496.0
# 83644  6b731083-d1e9-4b08-8718-0369011dff7d   Fully Paid             155474.0
# 83645                                   NaN          NaN                  NaN
#
#              Term  Credit Score  Annual Income Years in current job  \
# 0      Short Term         709.0      1167493.0              8 years
# 1      Short Term           NaN            NaN            10+ years
# 2      Short Term         741.0      2231892.0              8 years
# 3       Long Term         721.0       806949.0              3 years
# 4      Short Term           NaN            NaN              5 years
# ...           ...           ...            ...                  ...
# 83641  Short Term           NaN            NaN              3 years
# 83642  Short Term         700.0       578379.0              2 years
# 83643  Short Term         733.0      1686212.0            10+ years
# 83644  Short Term         731.0      1496079.0              2 years
# 83645         NaN           NaN            NaN                  NaN
#
#       Home Ownership             Purpose  Monthly Debt  \
# 0      Home Mortgage   Home Improvements       5214.74
# 1      Home Mortgage  Debt Consolidation      33295.98
# 2           Own Home  Debt Consolidation      29200.53
# 3           Own Home  Debt Consolidation       8741.90
# 4               Rent  Debt Consolidation      20639.70
# ...              ...                 ...           ...
# 83641           Rent  Debt Consolidation      17333.89
# 83642           Rent               Other       9013.03
# 83643  Home Mortgage  Debt Consolidation      32178.40
# 83644  Home Mortgage  Debt Consolidation      13464.73
# 83645            NaN                 NaN           NaN
#
#        Years of Credit History  Months since last delinquent  \
# 0                         17.2                           NaN
# 1                         21.1                           8.0
# 2                         14.9                          29.0
# 3                         12.0                           NaN
# 4                          6.1                           NaN
# ...                        ...                           ...
# 83641                     11.0                           NaN
# 83642                      9.5                           NaN
# 83643                     10.0                           NaN
# 83644                     17.6                          11.0
# 83645                      NaN                           NaN
#
#        Number of Open Accounts  Number of Credit Problems  \
# 0                          6.0                        1.0
# 1                         35.0                        0.0
# 2                         18.0                        1.0
# 3                          9.0                        0.0
# 4                         15.0                        0.0
# ...                        ...                        ...
# 83641                      7.0                        0.0
# 83642                      9.0                        0.0
# 83643                      8.0                        1.0
# 83644                     15.0                        1.0
# 83645                      NaN                        NaN
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 0                    228190.0             416746.0           1.0        0.0
# 1                    229976.0             850784.0           0.0        0.0
# 2                    297996.0             750090.0           0.0        0.0
# 3                    256329.0             386958.0           0.0        0.0
# 4                    253460.0             427174.0           0.0        0.0
# ...                       ...                  ...           ...        ...
# 83641                234308.0             288002.0           0.0        0.0
# 83642                179151.0             279180.0           0.0        0.0
# 83643                362672.0            1238754.0           1.0        0.0
# 83644                149283.0             815342.0           1.0        0.0
# 83645                     NaN                  NaN           NaN        NaN
#
# [83646 rows x 19 columns]

# %%
### checking columns
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         8.364500e+04  67572.000000   6.757200e+04   83645.000000
# mean          1.182523e+07   1075.399441   1.374488e+06   18446.664391
# std           3.186180e+07   1473.136585   9.182688e+05   12208.864816
# min           1.124200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.796520e+05    705.000000   8.491860e+05   10187.230000
# 50%           3.124660e+05    724.000000   1.169849e+06   16183.250000
# 75%           5.263060e+05    741.000000   1.648734e+06   23966.410000
# max           1.000000e+08   7510.000000   3.647544e+07  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count             83645.000000                  39200.000000
# mean                 18.189666                     34.961684
# std                   6.994789                     22.025434
# min                   3.600000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  16.900000                     32.000000
# 75%                  21.700000                     51.000000
# max                  70.500000                    176.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             83645.000000               83645.000000
# mean                 11.121059                   0.168414
# std                   4.992446                   0.484302
# min                   0.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  10.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  56.000000                  15.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            8.364500e+04         8.364400e+04  83485.000000  83636.000000
# mean             2.948539e+05         7.488010e+05      0.117949      0.028959
# std              3.804872e+05         7.947580e+06      0.351345      0.260600
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              1.126700e+05         2.731300e+05      0.000000      0.000000
# 50%              2.097980e+05         4.670710e+05      0.000000      0.000000
# 75%              3.675170e+05         7.825400e+05      0.000000      0.000000
# max              3.287897e+07         1.539738e+09      7.000000     15.000000

# %% [markdown]
# CHECKING NULL VALUES

# %%
df.isna().sum()
# Out:
# Loan ID                             0
# Customer ID                         1
# Loan Status                         1
# Current Loan Amount                 1
# Term                                1
# Credit Score                    16074
# Annual Income                   16074
# Years in current job             3545
# Home Ownership                      1
# Purpose                             1
# Monthly Debt                        1
# Years of Credit History             1
# Months since last delinquent    44446
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 2
# Bankruptcies                      161
# Tax Liens                          10
# dtype: int64

# %%
df.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# FILLING NULL VALUES

# %%
for i in df.columns:
  if df[i].dtypes==object:
    df[i]=df[i].fillna(df[i].mode()[0]) ##for object values
  else:
    df[i]=df[i].fillna(df[i].mean())  ##for numerical values

# %%
df.isna().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# # DESCRIPTIVE STATISTICS

# %%
for i in df.columns:
    if df[i].dtypes!=object:
        print(i)
        print()
        print(df[i].describe())
        print('**************************************************************************')
# Out:
# Current Loan Amount
#
# count    8.364600e+04
# mean     1.182523e+07
# std      3.186161e+07
# min      1.124200e+04
# 25%      1.796520e+05
# 50%      3.124660e+05
# 75%      5.263390e+05
# max      1.000000e+08
# Name: Current Loan Amount, dtype: float64
# **************************************************************************
# Credit Score
#
# count    83646.000000
# mean      1075.399441
# std       1324.046372
# min        585.000000
# 25%        711.000000
# 50%        733.000000
# 75%        750.000000
# max       7510.000000
# Name: Credit Score, dtype: float64
# **************************************************************************
# Annual Income
#
# count    8.364600e+04
# mean     1.374488e+06
# std      8.253345e+05
# min      7.662700e+04
# 25%      9.311900e+05
# 50%      1.367040e+06
# 75%      1.509113e+06
# max      3.647544e+07
# Name: Annual Income, dtype: float64
# **************************************************************************
# Monthly Debt
#
# count     83646.000000
# mean      18446.664391
# std       12208.791836
# min           0.000000
# 25%       10187.372500
# 50%       16183.250000
# 75%       23966.267500
# max      435843.280000
# Name: Monthly Debt, dtype: float64
# **************************************************************************
# Years of Credit History
#
# count    83646.000000
# mean        18.189666
# std          6.994747
# min          3.600000
# 25%         13.500000
# 50%         16.900000
# 75%         21.700000
# max         70.500000
# Name: Years of Credit History, dtype: float64
# **************************************************************************
# Months since last delinquent
#
# count    83646.000000
# mean        34.961684
# std         15.077939
# min          0.000000
# 25%         34.000000
# 50%         34.961684
# 75%         34.961684
# max        176.000000
# Name: Months since last delinquent, dtype: float64
# **************************************************************************
# Number of Open Accounts
#
# count    83646.000000
# mean        11.121059
# std          4.992416
# min          0.000000
# 25%          8.000000
# 50%         10.000000
# 75%         14.000000
# max         56.000000
# Name: Number of Open Accounts, dtype: float64
# **************************************************************************
# Number of Credit Problems
#
# count    83646.000000
# mean         0.168414
# std          0.484299
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         15.000000
# Name: Number of Credit Problems, dtype: float64
# **************************************************************************
# Current Credit Balance
#
# count    8.364600e+04
# mean     2.948539e+05
# std      3.804849e+05
# min      0.000000e+00
# 25%      1.126700e+05
# 50%      2.097980e+05
# 75%      3.675170e+05
# max      3.287897e+07
# Name: Current Credit Balance, dtype: float64
# **************************************************************************
# Maximum Open Credit
#
# count    8.364600e+04
# mean     7.488010e+05
# std      7.947485e+06
# min      0.000000e+00
# 25%      2.731355e+05
# 50%      4.670820e+05
# 75%      7.825290e+05
# max      1.539738e+09
# Name: Maximum Open Credit, dtype: float64
# **************************************************************************
# Bankruptcies
#
# count    83646.000000
# mean         0.117949
# std          0.351007
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          7.000000
# Name: Bankruptcies, dtype: float64
# **************************************************************************
# Tax Liens
#
# count    83646.000000
# mean         0.028959
# std          0.260585
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         15.000000
# Name: Tax Liens, dtype: float64
# **************************************************************************

# %%
import seaborn as sns

# %%
from matplotlib.pyplot import show
for i in df.columns:
    if df[i].dtypes!=object:
        sns.histplot(data=df,x=i,kde=True)
        print(i)
        show()
# Out:
# Current Loan Amount
# Credit Score
# Annual Income
# Monthly Debt
# Years of Credit History
# Months since last delinquent
# Number of Open Accounts
# Number of Credit Problems
# Current Credit Balance
# Maximum Open Credit
# Bankruptcies
# Tax Liens

# %% [markdown]
# **CORRELATION**

# %%
cat=[]
con=[]
for i in df.columns:
  if df[i].dtypes==object:
    cat.append(i)
  else:
    con.append(i)
print('cat:',cat)
print('con:',con)
# Out:
# cat: ['Loan ID', 'Customer ID', 'Loan Status', 'Term', 'Years in current job', 'Home Ownership', 'Purpose']
# con: ['Current Loan Amount', 'Credit Score', 'Annual Income', 'Monthly Debt', 'Years of Credit History', 'Months since last delinquent', 'Number of Open Accounts', 'Number of Credit Problems', 'Current Credit Balance', 'Maximum Open Credit', 'Bankruptcies', 'Tax Liens']

# %%
xcat=df[cat]
xcon=df[con]

# %%
xcon.corr()  ##checking correlations
# Out:
#                               Current Loan Amount  Credit Score  \
# Current Loan Amount                      1.000000 -9.531562e-02
# Credit Score                            -0.095316  1.000000e+00
# Annual Income                            0.016384 -2.911485e-02
# Monthly Debt                            -0.005725 -2.958925e-03
# Years of Credit History                  0.020123 -8.834549e-03
# Months since last delinquent             0.006647 -2.542874e-03
# Number of Open Accounts                  0.001167  3.765303e-03
# Number of Credit Problems               -0.002404 -1.228569e-03
# Current Credit Balance                   0.002029 -2.407545e-07
# Maximum Open Credit                     -0.000401 -1.809370e-03
# Bankruptcies                            -0.000924 -4.426962e-03
# Tax Liens                               -0.001176  4.034544e-03
#
#                               Annual Income  Monthly Debt  \
# Current Loan Amount                0.016384     -0.005725
# Credit Score                      -0.029115     -0.002959
# Annual Income                      1.000000      0.517087
# Monthly Debt                       0.517087      1.000000
# Years of Credit History            0.171855      0.196427
# Months since last delinquent      -0.050365     -0.037647
# Number of Open Accounts            0.154859      0.410709
# Number of Credit Problems         -0.018693     -0.054604
# Current Credit Balance             0.339515      0.481008
# Maximum Open Credit                0.047120      0.042500
# Bankruptcies                      -0.050607     -0.077599
# Tax Liens                          0.041517      0.019718
#
#                               Years of Credit History  \
# Current Loan Amount                          0.020123
# Credit Score                                -0.008835
# Annual Income                                0.171855
# Monthly Debt                                 0.196427
# Years of Credit History                      1.000000
# Months since last delinquent                -0.031281
# Number of Open Accounts                      0.129113
# Number of Credit Problems                    0.062493
# Current Credit Balance                       0.206571
# Maximum Open Credit                          0.031532
# Bankruptcies                                 0.069105
# Tax Liens                                    0.015157
#
#                               Months since last delinquent  \
# Current Loan Amount                               0.006647
# Credit Score                                     -0.002543
# Annual Income                                    -0.050365
# Monthly Debt                                     -0.037647
# Years of Credit History                          -0.031281
# Months since last delinquent                      1.000000
# Number of Open Accounts                          -0.021738
# Number of Credit Problems                         0.081113
# Current Credit Balance                           -0.016570
# Maximum Open Credit                              -0.005030
# Bankruptcies                                      0.089642
# Tax Liens                                         0.010463
#
#                               Number of Open Accounts  \
# Current Loan Amount                          0.001167
# Credit Score                                 0.003765
# Annual Income                                0.154859
# Monthly Debt                                 0.410709
# Years of Credit History                      0.129113
# Months since last delinquent                -0.021738
# Number of Open Accounts                      1.000000
# Number of Credit Problems                   -0.012912
# Current Credit Balance                       0.228543
# Maximum Open Credit                          0.035341
# Bankruptcies                                -0.025107
# Tax Liens                                    0.008731
#
#                               Number of Credit Problems  \
# Current Loan Amount                           -0.002404
# Credit Score                                  -0.001229
# Annual Income                                 -0.018693
# Monthly Debt                                  -0.054604
# Years of Credit History                        0.062493
# Months since last delinquent                   0.081113
# Number of Open Accounts                       -0.012912
# Number of Credit Problems                      1.000000
# Current Credit Balance                        -0.110498
# Maximum Open Credit                           -0.011753
# Bankruptcies                                   0.750072
# Tax Liens                                      0.583751
#
#                               Current Credit Balance  Maximum Open Credit  \
# Current Loan Amount                     2.029389e-03            -0.000401
# Credit Score                           -2.407545e-07            -0.001809
# Annual Income                           3.395148e-01             0.047120
# Monthly Debt                            4.810084e-01             0.042500
# Years of Credit History                 2.065709e-01             0.031532
# Months since last delinquent           -1.656980e-02            -0.005030
# Number of Open Accounts                 2.285426e-01             0.035341
# Number of Credit Problems              -1.104975e-01            -0.011753
# Current Credit Balance                  1.000000e+00             0.144503
# Maximum Open Credit                     1.445032e-01             1.000000
# Bankruptcies                           -1.212568e-01            -0.014779
# Tax Liens                              -1.396585e-02            -0.000417
#
#                               Bankruptcies  Tax Liens
# Current Loan Amount              -0.000924  -0.001176
# Credit Score                     -0.004427   0.004035
# Annual Income                    -0.050607   0.041517
# Monthly Debt                     -0.077599   0.019718
# Years of Credit History           0.069105   0.015157
# Months since last delinquent      0.089642   0.010463
# Number of Open Accounts          -0.025107   0.008731
# Number of Credit Problems         0.750072   0.583751
# Current Credit Balance           -0.121257  -0.013966
# Maximum Open Credit              -0.014779  -0.000417
# Bankruptcies                      1.000000   0.045921
# Tax Liens                         0.045921   1.000000

# %%
sns.heatmap(xcon.corr(),annot=True)
# Out:
# <Axes: >

# %%
xcon.corr()['Current Credit Balance'].sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **PAIR PLOT**

# %%
sns.pairplot(data=xcon)

# %% [markdown]
# ADVANCE ANALYSIS

# %%
## 1.What is the average current loan amount for each loan status?
averages=df.groupby(by='Loan Status')['Current Loan Amount'].mean()
print('The average current loan amount for each loan status are:')
print(averages)
# Out:
# The average current loan amount for each loan status are:
# Loan Status
# Charged Off    3.261467e+05
# Fully Paid     1.517779e+07
# Name: Current Loan Amount, dtype: float64

# %%
averages.plot(kind='bar')
plt.title('Average current loan amount for each loan status')
plt.xlabel('Loan Status')
plt.ylabel('Average Current Loan Amount')
plt.show()

# %%
## 2.How does the credit score vary with the annual income?
sns.scatterplot(data=df,x='Annual Income',y='Credit Score',c='red')
plt.title('Credit Score vs Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Credit Score')
plt.show()

# %%
## 3.Is there a correlation between the number of open accounts and the current credit balance?
correlation=df['Number of Open Accounts'].corr(df['Current Credit Balance'])
print('The correlation between the number of open accounts and the current credit balance is:',)
print(correlation)
# Out:
# The correlation between the number of open accounts and the current credit balance is:
# 0.22854264797756182

# %%
## 0 indicates no linear relationship.

# %%
##4.What is the distribution of credit scores across different home ownership types?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Home Ownership', y='Credit Score', data=df)
plt.title('Distribution of Credit Scores Across Home Ownership Types')
plt.xlabel('Home Ownership')
plt.ylabel('Credit Score')
plt.tight_layout()
plt.show()

# %%
## 5.How does the annual income differ for different purposes of loans?
sns.boxplot(x='Purpose', y='Annual Income', data=df)
plt.title('Annual Income Across Loan Purposes')
plt.xlabel('Loan Purpose')
plt.ylabel('Annual Income')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
## 6.What is the average monthly debt for each term (short-term vs. long-term)?
averages=df.groupby(by='Term')['Monthly Debt'].mean()
print('The average monthly debt for each term are:')
print(averages)
# Out:
# The average monthly debt for each term are:
# Term
# Long Term     21622.883239
# Short Term    17221.544642
# Name: Monthly Debt, dtype: float64

# %%
averages.plot(kind='pie',autopct='%1.1f%%')
plt.title('Average monthly debt for each term')
plt.show()

# %%
## 7.Is there a correlation between years of credit history and the current credit balance?
correlation=df['Years of Credit History'].corr(df['Current Credit Balance'])
print('The correlation between years of credit history and the current credit balance is:',)
print(correlation)
# Out:
# The correlation between years of credit history and the current credit balance is:
# 0.20657093623039108

# %%
# 0 indicates no linear relationship.

# %%
## 8.How does the credit score vary with the years in the current job?
plt.scatter(df['Years in current job'], df['Credit Score'], color='purple')
plt.title('Credit Score vs Years in Current Job')
plt.xlabel('Years in Current Job')
plt.ylabel('Credit Score')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
##9.What is the relationship between the number of credit problems and the number of open accounts?
sns.scatterplot(x='Number of Credit Problems', y='Number of Open Accounts', data=df,c='grey',marker='^')
plt.title('Relationship between Number of Credit Problems and Number of Open Accounts')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Number of Open Accounts')
# Out:
# Text(0, 0.5, 'Number of Open Accounts')

# %%
## 10.What is the distribution of annual income across different loan statuses?
sns.boxplot(x='Loan Status', y='Annual Income', data=df)
plt.title('Distribution of Annual Income Across Loan Statuses')
plt.xlabel('Loan Status')
plt.ylabel('Annual Income')
plt.show()

# %%
##11.Is there a correlation between the current loan amount and the number of open accounts?
correlation=df['Current Loan Amount'].corr(df['Number of Open Accounts'])
print('The correlation between the current loan amount and the number of open accounts is:',)
print(correlation)
# Out:
# The correlation between the current loan amount and the number of open accounts is:
# 0.0011668092084059466

# %%
# 0 indicates no linear relationship.

# %%
##12.How does the monthly debt vary with the years of credit history?
sns.scatterplot(x='Years of Credit History', y='Monthly Debt', data=df,c='green')
plt.title('Monthly Debt vs Years of Credit History')
plt.xlabel('Years of Credit History')
plt.ylabel('Monthly Debt')
# Out:
# Text(0, 0.5, 'Monthly Debt')

# %%
##13.What is the average annual income for each purpose of loan?
averages=df.groupby(by='Purpose')['Annual Income'].mean()
print('The average annual income for each purpose of loan are:')
print(averages)
# Out:
# The average annual income for each purpose of loan are:
# Purpose
# Business Loan           1.542991e+06
# Buy House               1.481699e+06
# Buy a Car               1.250869e+06
# Debt Consolidation      1.359687e+06
# Educational Expenses    1.046241e+06
# Home Improvements       1.618542e+06
# Medical Bills           1.429056e+06
# Other                   1.351665e+06
# Take a Trip             1.245441e+06
# major_purchase          1.386728e+06
# moving                  1.552481e+06
# other                   1.305136e+06
# renewable_energy        1.427724e+06
# small_business          1.558732e+06
# vacation                1.252621e+06
# wedding                 1.417461e+06
# Name: Annual Income, dtype: float64

# %%
averages.plot(kind='bar')
plt.title('Average annual income for each purpose of loan')
plt.xlabel('Purpose of Loan')
plt.ylabel('Average Annual Income')
plt.show()

# %%
## 14.How does the credit score vary with the number of credit problems?
sns.scatterplot(x='Number of Credit Problems', y='Credit Score', data=df,c='orange')
plt.title('Credit Score vs Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Credit Score')
# Out:
# Text(0, 0.5, 'Credit Score')

# %%
## 15.Is there a correlation between the number of credit problems and the current credit balance?
correlation=df['Number of Credit Problems'].corr(df['Current Credit Balance'])
print('The correlation between the number of credit problems and the current credit balance is:',)
print(correlation)
# Out:
# The correlation between the number of credit problems and the current credit balance is:
# -0.11049753625144257

# %%
## it has negative linear relationship

# %%
## 16.What is the distribution of current loan amounts across different home ownership types?
sns.boxplot(x='Home Ownership', y='Current Loan Amount', data=df)
plt.title('Distribution of Current Loan Amounts Across Home Ownership Types')
plt.xlabel('Home Ownership')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
##17.How does the annual income vary with the years in the current job?
sns.scatterplot(x='Years in current job', y='Annual Income', data=df,c='red')
plt.title('Annual Income vs Years in Current Job')
plt.xlabel('Years in Current Job')
plt.xticks(rotation=90)
plt.ylabel('Annual Income')
# Out:
# Text(0, 0.5, 'Annual Income')

# %%
##18.Is there a correlation between the current loan amount and the monthly debt?
correlation=df['Current Loan Amount'].corr(df['Monthly Debt'])
print('The correlation between the current loan amount and the monthly debt is:',)
print(correlation)
# Out:
# The correlation between the current loan amount and the monthly debt is:
# -0.005725055563737517

# %%
##It has negative linear relationship

# %%
 ## 19.What is the average monthly debt for each home ownership type?
 averages=df.groupby(by='Home Ownership')['Monthly Debt'].mean()
print('The average monthly debt for each home ownership type are:')
print(averages)
# Out:
# The average monthly debt for each home ownership type are:
# Home Ownership
# HaveMortgage     18886.928663
# Home Mortgage    21023.435116
# Own Home         17082.538105
# Rent             15782.246425
# Name: Monthly Debt, dtype: float64

# %%
averages.plot(kind='bar')
plt.title('Average monthly debt for each home ownership type')
plt.xlabel('Home Ownership')
plt.ylabel('Average Monthly Debt')
plt.show()

# %%
##20.How does the credit score vary with the number of open accounts?
sns.scatterplot(x='Number of Open Accounts', y='Credit Score', data=df,c='pink')
plt.title('Credit Score vs Number of Open Accounts')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Credit Score')
# Out:
# Text(0, 0.5, 'Credit Score')

# %%
## 21.What is the distribution of credit scores across different loan statuses?
sns.boxplot(x='Loan Status', y='Credit Score', data=df)
plt.title('Distribution of Credit Scores Across Loan Statuses')
plt.xlabel('Loan Status')
plt.ylabel('Credit Score')
plt.show()

# %%
## 22.Is there a correlation between the current loan amount and the years of credit history?
correlation=df['Current Loan Amount'].corr(df['Years of Credit History'])
print('The correlation between the current loan amount and the years of credit history is:',)
print(correlation)
# Out:
# The correlation between the current loan amount and the years of credit history is:
# 0.020123325052525745

# %%
## # 0 indicates no linear relationship.

# %%
## 23.How does the monthly debt vary with the number of credit problems?
sns.scatterplot(x='Number of Credit Problems', y='Monthly Debt', data=df,c='purple')
plt.title('Monthly Debt vs Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Monthly Debt')
# Out:
# Text(0, 0.5, 'Monthly Debt')

# %%
##24.What is the average current loan amount for each purpose of loan?
averages=df.groupby(by='Purpose')['Current Loan Amount'].mean()
print('The average current loan amount for each purpose of loan are:')
print(averages)
# Out:
# The average current loan amount for each purpose of loan are:
# Purpose
# Business Loan           7.943611e+06
# Buy House               1.075996e+07
# Buy a Car               1.440001e+07
# Debt Consolidation      1.184019e+07
# Educational Expenses    1.410161e+07
# Home Improvements       1.280914e+07
# Medical Bills           1.239806e+07
# Other                   1.269247e+07
# Take a Trip             1.121297e+07
# major_purchase          1.317675e+07
# moving                  1.294969e+07
# other                   1.066075e+07
# renewable_energy        1.216188e+05
# small_business          9.663605e+06
# vacation                6.078186e+06
# wedding                 1.999762e+07
# Name: Current Loan Amount, dtype: float64

# %%
averages.plot(kind='bar')
plt.title('Average current loan amount for each purpose of loan')
plt.xlabel('Purpose of Loan')
plt.ylabel('Average Current Loan Amount')
plt.show()

# %%
##25.How does the credit score vary with the current credit balance?
sns.scatterplot(x='Current Credit Balance', y='Credit Score', data=df,c='green')
plt.title('Credit Score vs Current Credit Balance')
plt.xlabel('Current Credit Balance')
plt.ylabel('Credit Score')
# Out:
# Text(0, 0.5, 'Credit Score')

# %%
## 26.Is there a correlation between the annual income and the current credit balance?
correlation=df['Annual Income'].corr(df['Current Credit Balance'])
print('The correlation between the annual income and the current credit balance is:',)
print(correlation)
# Out:
# The correlation between the annual income and the current credit balance is:
# 0.33951479157943454

# %%
# 0 indicates no linear relationship.

# %%
##27.What is the distribution of annual income across different terms (short-term vs. long-term)?
sns.boxplot(x='Term', y='Annual Income', data=df)
plt.title('Distribution of Annual Income Across Terms')
plt.xlabel('Term')
plt.ylabel('Annual Income')
plt.show()

# %%
##28.How does the credit score vary with the number of credit problems?
sns.scatterplot(x='Number of Credit Problems', y='Credit Score', data=df,c='orange')
plt.title('Credit Score vs Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Credit Score')
# Out:
# Text(0, 0.5, 'Credit Score')

# %%
##29.Is there a correlation between the current loan amount and the number of credit problems?
correlation=df['Current Loan Amount'].corr(df['Number of Credit Problems'])
print('The correlation between the current loan amount and the number of credit problems is:',)
print(correlation)
# Out:
# The correlation between the current loan amount and the number of credit problems is:
# -0.002404221461632168

# %%
# It has a negative linear relationship

# %%
##30.What is the relationship between the number of open accounts and the years of credit history?
relationship=df['Number of Open Accounts'].corr(df['Years of Credit History'])
print('The relationship between the number of open accounts and the years of credit history is:',)
print(relationship)
# Out:
# The relationship between the number of open accounts and the years of credit history is:
# 0.12911348282764074

# %%
plt.scatter(df['Number of Open Accounts'], df['Years of Credit History'])
plt.title('Relationship between Number of Open Accounts and Years of Credit History')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Years of Credit History')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
